# %% [markdown]
# <a href="https://colab.research.google.com/github/jinju-yang/DACOS_NLP/blob/main/POP_lyrics_emotion_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-translator
from deep_translator import GoogleTranslator
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import pandas as pd
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
translator = GoogleTranslator(source='ko', target='en')

#GoEmotions 모델 사용
model_name = "monologg/bert-base-cased-goemotions-original"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

emotion_analyzer = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer, return_all_scores=True)

# 표제어 추출 및 불용어 리스트
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

stopwords = set(stopwords.words('english'))

lemmatizer = WordNetLemmatizer()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
def preprocess_lyrics_english(lyric):
    lyric = re.sub(r'<.*?>', '', lyric)  # HTML 태그 제거
    lyric = re.sub(r'http\S+|www\S+', '', lyric)  # URL 제거
    lyric = re.sub(r'[^\w\s]', '', lyric)  # 특수 문자 제거
    lyric = re.sub(r'\d+', '', lyric)  # 숫자 제거

    lyric = lyric.lower()

    # 3. 공백 기준 토큰화
    tokens = lyric.split()

    processed_tokens = []
    for token in tokens:
        if token not in stopwords:
            lemma = lemmatizer.lemmatize(token)
            processed_tokens.append(lemma)
    return " ".join(processed_tokens)

# CSV 파일 불러오기
df = pd.read_csv("melon_pop_lyrics_1_200.csv")

# '곡 제목', '가수', '가사' 컬럼만 사용한다고 가정
df = df[['곡 제목', '가수', '가사']]

df['감정'] = ''
df['score'] = ''

# %%
for idx, (song_name, artist, lyric) in enumerate(zip(df['곡 제목'], df['가수'], df['가사'])):
    if pd.isna(lyric):
        print(f"곡 제목: {song_name}의 가사가 비어 있습니다. 건너뜁니다.")
        continue  # NaN일 경우 이 항목을 건너뜁니다.

    # 한국어 가사 -> 영어 번역
    translated_lyric = translator.translate(lyric)

    # 영어로 번역된 가사 전처리
    processed_lyric = preprocess_lyrics_english(translated_lyric)

    # 감정 분석
    result = emotion_analyzer(processed_lyric)

    # 감정 분석 결과 처리
    high_confidence_emotions = [r for r in result[0] if r['score'] >= 0.9]
    if high_confidence_emotions:
        top_emotion = max(high_confidence_emotions, key=lambda x: x['score'])
        emotion = top_emotion['label']
        score = top_emotion['score']
    else:
        sorted_emotions = sorted(result[0], key=lambda x: x['score'], reverse=True)
        top_emotions = sorted_emotions[:2]
        emotion = ", ".join([e['label'] for e in top_emotions])
        score = ", ".join([str(e['score']) for e in top_emotions])

    # 중간 결과 출력 (선택 사항)
    print(f"곡 제목: {song_name}, 감정: {emotion}, score: {score}")

    # 결과를 데이터프레임에 저장
    df.at[idx, '감정'] = emotion
    df.at[idx, 'score'] = score
# Out:
# 곡 제목: I Don't Think That I Like Her, 감정: neutral, disappointment, score: 0.8590247631072998, 0.06776775419712067
# 곡 제목: STAY, 감정: fear, score: 0.9826462268829346
# 곡 제목: Dangerously, 감정: love, score: 0.9961769580841064
# 곡 제목: Steal The Show (From "Elemental"), 감정: neutral, score: 0.9984843134880066
# 곡 제목: 2002, 감정: love, score: 0.954855740070343
# 곡 제목: Die With A Smile, 감정: neutral, love, score: 0.810812771320343, 0.1854088008403778
# 곡 제목: Off My Face, 감정: love, score: 0.9906241297721863
# 곡 제목: Love Yourself, 감정: love, score: 0.9995469450950623
# 곡 제목: Older, 감정: love, disapproval, score: 0.8511183261871338, 0.10517122596502304
# 곡 제목: pocket locket, 감정: love, score: 0.9974852800369263
# 곡 제목: Shape of You, 감정: love, score: 0.9997206330299377
# 곡 제목: Cruel Summer, 감정: anger, neutral, score: 0.7263177037239075, 0.10595846176147461
# 곡 제목: Touch, 감정: love, score: 0.9998399019241333
# 곡 제목: When I Get Old, 감정: fear, score: 0.9862307906150818
# 곡 제목: Memories, 감정: neutral, score: 0.9995562434196472
# 곡 제목: Beautiful Things, 감정: gratitude, fear, score: 0.8528051972389221, 0.12023317813873291
# 곡 제목: Espresso, 감정: neutral, score: 0.9999812841415405
# 곡 제목: These Tears, 감정: sadness, love, score: 0.7485904693603516, 0.12382811307907104
# 곡 제목: Loving You Girl (Feat. Hkeem), 감정: love, score: 0.9662409424781799
# 곡 제목: Paris in the Rain, 감정: neutral, realization, score: 0.8391712307929993, 0.08502563834190369
# 곡 제목: Snowman, 감정: neutral, love, score: 0.7214215993881226, 0.14870266616344452
# 곡 제목: I'm Not The Only One, 감정: fear, love, score: 0.8275426626205444, 0.12487653642892838
# 곡 제목: 12:45 (Stripped), 감정: love, score: 0.9987145662307739
# 곡 제목: There's Nothing Holdin' Me Back, 감정: love, score: 0.9868239164352417
# 곡 제목: comethru, 감정: realization, score: 0.9987820982933044
# 곡 제목: YOUTH, 감정: neutral, score: 0.9999896287918091
# 곡 제목: Sugar, 감정: love, score: 0.9988707900047302
# 곡 제목: One Call Away, 감정: love, score: 0.9374227523803711
# 곡 제목: That's Hilarious, 감정: amusement, score: 0.9994670748710632
# 곡 제목: Bad, 감정: neutral, score: 0.9965974688529968
# 곡 제목: I Like Me Better, 감정: love, score: 0.9961010217666626
# 곡 제목: Santa Tell Me, 감정: love, score: 0.9971539974212646
# 곡 제목: Rewrite The Stars, 감정: neutral, score: 0.9999830722808838
# 곡 제목: double take, 감정: love, score: 0.9988798499107361
# 곡 제목: Moonlit Floor (Kiss Me), 감정: neutral, score: 0.9999094009399414
# 곡 제목: 24/7, 365, 감정: love, score: 0.9994895458221436
# 곡 제목: That’s Not How This Works (feat. Dan + Shay), 감정: anger, score: 0.9105332493782043
# 곡 제목: Trouble, 감정: caring, annoyance, score: 0.505679190158844, 0.1434163898229599
# 곡 제목: As It Was, 감정: neutral, score: 0.9996911287307739
# 곡 제목: Every Second, 감정: fear, neutral, score: 0.8569682240486145, 0.09016207605600357
# 곡 제목: drunk text, 감정: fear, score: 0.9991776347160339
# 곡 제목: We Don't Talk Anymore (feat. Selena Gomez), 감정: fear, love, score: 0.8932725191116333, 0.08067444711923599
# 곡 제목: Believer, 감정: love, score: 0.9987605810165405
# 곡 제목: Maniac, 감정: neutral, disapproval, score: 0.27557939291000366, 0.2610473036766052
# 곡 제목: Always Remember Us This Way, 감정: neutral, score: 0.9149497747421265
# 곡 제목: Perfect, 감정: love, score: 0.9993484616279602
# 곡 제목: Architect, 감정: gratitude, score: 0.9005857110023499
# 곡 제목: 7 Years, 감정: love, score: 0.9204303622245789
# 곡 제목: Like Strangers Do, 감정: neutral, score: 0.9999885559082031
# 곡 제목: Dance Monkey, 감정: neutral, surprise, score: 0.7063020467758179, 0.1935395747423172
# 곡 제목: Fall In Love Alone, 감정: love, confusion, score: 0.668069064617157, 0.23795662820339203
# 곡 제목: Attention, 감정: remorse, anger, score: 0.6361684203147888, 0.15755882859230042
# 곡 제목: What Makes You Beautiful, 감정: surprise, disapproval, score: 0.5827338099479675, 0.12599527835845947
# 곡 제목: That's What I Like, 감정: neutral, score: 0.9351341724395752
# 곡 제목: Stuck with U, 감정: neutral, score: 0.9663938879966736
# 곡 제목: Uptown Funk (Feat. Bruno Mars), 감정: neutral, confusion, score: 0.8729472756385803, 0.12358295172452927
# 곡 제목: parachute, 감정: neutral, score: 0.9790248274803162
# 곡 제목: Here With Me, 감정: desire, score: 0.9048511385917664
# 곡 제목: bad guy, 감정: neutral, score: 0.9642532467842102
# 곡 제목: Don't Start Now, 감정: fear, score: 0.9789072871208191
# 곡 제목: Bad Habits, 감정: disappointment, score: 0.9390912055969238
# 곡 제목: Left and Right (Feat. Jung Kook of BTS), 감정: love, score: 0.9991631507873535
# 곡 제목: Dancing With Your Ghost, 감정: love, score: 0.9996125102043152
# 곡 제목: 晩餐歌, 감정: neutral, score: 0.9557900428771973
# 곡 제목: Like 1999, 감정: love, score: 0.995783805847168
# 곡 제목: Obsessed, 감정: love, score: 0.9943670630455017
# 곡 제목: BIRDS OF A FEATHER, 감정: love, score: 0.9984657764434814
# 곡 제목: Stronger (What Doesn't Kill You), 감정: disapproval, neutral, score: 0.8792497515678406, 0.08961498737335205
# 곡 제목: Flower, 감정: love, score: 0.9430684447288513
# 곡 제목: Never Not, 감정: love, disappointment, score: 0.7939391136169434, 0.12333876639604568
# 곡 제목: Rockstar, 감정: neutral, score: 0.999213457107544
# 곡 제목: Tango, 감정: remorse, caring, score: 0.5652551651000977, 0.2571364939212799
# 곡 제목: Touch (ft. YEONJUN of TOMORROW X TOGETHER), 감정: love, score: 0.999795138835907
# 곡 제목: Baby (Feat. Ludacris), 감정: love, score: 0.9996339082717896
# 곡 제목: High Hopes, 감정: confusion, neutral, score: 0.759005069732666, 0.1789126694202423
# 곡 제목: Painkiller, 감정: neutral, score: 0.9952518939971924
# 곡 제목: All 4 Nothing (I'm So In Love), 감정: love, score: 0.9994361996650696
# 곡 제목: a thousand years, 감정: love, score: 0.9298316240310669
# 곡 제목: Last Christmas, 감정: neutral, love, score: 0.837051272392273, 0.144599050283432
# 곡 제목: Ashes, 감정: love, anger, score: 0.7587260603904724, 0.11737358570098877
# 곡 제목: Peaches (Feat. Daniel Caesar & Giveon)의 가사가 비어 있습니다. 건너뜁니다.
# 곡 제목: Underneath The Tree, 감정: love, score: 0.9589521884918213
# 곡 제목: always, i'll care, 감정: caring, disappointment, score: 0.8900893330574036, 0.05020500347018242
# 곡 제목: Angel Baby, 감정: fear, score: 0.9976904392242432
# 곡 제목: To Die For, 감정: confusion, score: 0.9788349866867065
# 곡 제목: Savage Love (Laxed - Siren Beat) (BTS Remix), 감정: love, score: 0.9962932467460632
# 곡 제목: Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound), 감정: love, neutral, score: 0.632166862487793, 0.35647428035736084
# 곡 제목: Leave Before You Love Me, 감정: love, sadness, score: 0.7876411080360413, 0.19156216084957123
# 곡 제목: New Woman (Feat. ROSALÍA), 감정: neutral, score: 0.9999754428863525
# 곡 제목: Light Switch, 감정: neutral, score: 0.9618536233901978
# 곡 제목: Sunroof, 감정: neutral, score: 0.9999784231185913
# 곡 제목: 7 rings, 감정: neutral, score: 0.9985822439193726
# 곡 제목: Ghost Town, 감정: love, score: 0.969202995300293
# 곡 제목: Bonfire, 감정: love, score: 0.9995681643486023
# 곡 제목: Unstoppable, 감정: fear, score: 0.9959700107574463
# 곡 제목: Payphone (Feat. Wiz Khalifa), 감정: love, score: 0.9991540908813477
# 곡 제목: Thunder, 감정: neutral, score: 0.9999836683273315
# 곡 제목: Love Story, 감정: love, score: 0.9795624017715454
# 곡 제목: This Is Me, 감정: fear, score: 0.9933591485023499
# 곡 제목: High, 감정: neutral, score: 0.9975261092185974
# 곡 제목: Make It To Christmas, 감정: love, score: 0.9768781661987305
# 곡 제목: Watermelon Sugar, 감정: neutral, score: 0.9985802173614502
# 곡 제목: thank u, next, 감정: gratitude, score: 0.9894716143608093
# 곡 제목: Chandelier, 감정: love, score: 0.994847297668457
# 곡 제목: Unholy, 감정: neutral, score: 0.9113078713417053
# 곡 제목: If the World Was Ending (Feat. Julia Michaels), 감정: fear, neutral, score: 0.6345629692077637, 0.27266931533813477
# 곡 제목: Señorita, 감정: love, score: 0.997636079788208
# 곡 제목: Someone You Loved, 감정: love, score: 0.9853807091712952
# 곡 제목: Ring Pop, 감정: neutral, score: 0.9999371767044067
# 곡 제목: Kiss Me More (Feat. SZA), 감정: love, score: 0.9588833451271057
# 곡 제목: HandClap, 감정: neutral, score: 0.9999804496765137
# 곡 제목: Speechless (Full) (From "Aladdin"/Soundtrack Version), 감정: neutral, score: 0.9993242025375366
# 곡 제목: My Universe, 감정: desire, love, score: 0.8708955645561218, 0.08858555555343628
# 곡 제목: Tiny Riot, 감정: neutral, score: 0.9881594181060791
# 곡 제목: Please Please Please, 감정: embarrassment, love, score: 0.5803090333938599, 0.2371409386396408
# 곡 제목: abcdefu의 가사가 비어 있습니다. 건너뜁니다.
# 곡 제목: Champagne Problems, 감정: neutral, love, score: 0.580428957939148, 0.41620656847953796
# 곡 제목: Strawberries & Cigarettes, 감정: neutral, score: 0.959395170211792
# 곡 제목: Changes, 감정: optimism, score: 0.9952432513237
# 곡 제목: Paper Plane, 감정: optimism, score: 0.9959452748298645
# 곡 제목: Numb Little Bug, 감정: love, score: 0.973016083240509
# 곡 제목: dna, 감정: love, score: 0.9991768002510071
# 곡 제목: Love U Like That, 감정: love, score: 0.999643087387085
# 곡 제목: Here With Me, 감정: desire, score: 0.983994722366333
# 곡 제목: Mad at Disney, 감정: love, score: 0.9836581349372864
# 곡 제목: idontwannabeyouanymore, 감정: neutral, score: 0.9970614314079285
# 곡 제목: A LOT, 감정: neutral, score: 0.9999055862426758
# 곡 제목: cheap sunglasses, 감정: excitement, neutral, score: 0.54594886302948, 0.19031326472759247
# 곡 제목: Shallow, 감정: neutral, score: 0.9990411400794983
# 곡 제목: Stack It Up (Feat. A Boogie wit da Hoodie), 감정: neutral, score: 0.9997875094413757
# 곡 제목: Falling, 감정: neutral, score: 0.9999746084213257
# 곡 제목: (They Long To Be) Close To You, 감정: neutral, score: 0.9996331930160522
# 곡 제목: I'm Yours, 감정: love, score: 0.9696813821792603
# 곡 제목: When We Were Young, 감정: fear, score: 0.937263548374176
# 곡 제목: 305, 감정: fear, score: 0.9974799752235413
# 곡 제목: Lemon Tree, 감정: neutral, annoyance, score: 0.46023672819137573, 0.2563154697418213
# 곡 제목: Sunday Morning, 감정: neutral, score: 0.9998399019241333
# 곡 제목: Last Christmas, 감정: love, score: 0.9990148544311523
# 곡 제목: Flowers, 감정: love, score: 0.9959967136383057
# 곡 제목: Blank Space, 감정: love, score: 0.9937884211540222
# 곡 제목: Text Me Merry Christmas (Feat. Kristen Bell), 감정: love, score: 0.9939507246017456
# 곡 제목: Know Me Too Well, 감정: amusement, score: 0.9910996556282043
# 곡 제목: Christmas Without You, 감정: optimism, score: 0.9988223910331726
# 곡 제목: I'm Not The Only One, 감정: fear, score: 0.9841775894165039
# 곡 제목: Sorry, 감정: remorse, score: 0.9604459404945374
# 곡 제목: My Love, 감정: love, score: 0.9990046620368958
# 곡 제목: Bad Boy, 감정: neutral, anger, score: 0.5478922724723816, 0.42129167914390564
# 곡 제목: i'm so tired..., 감정: neutral, score: 0.999591052532196
# 곡 제목: Havana (Feat. Young Thug), 감정: neutral, score: 0.9951230883598328
# 곡 제목: Left Right Left, 감정: remorse, sadness, score: 0.3605884909629822, 0.3101058006286621
# 곡 제목: Counting Stars, 감정: love, score: 0.9928361773490906
# 곡 제목: Dive, 감정: love, optimism, score: 0.7513988018035889, 0.11853259801864624
# 곡 제목: Made You Look, 감정: neutral, score: 0.9933226704597473
# 곡 제목: Intrusive Thoughts, 감정: love, score: 0.9856202602386475
# 곡 제목: Burn the House Down, 감정: anger, score: 0.944098949432373
# 곡 제목: pick up the phone, 감정: nervousness, caring, score: 0.49748027324676514, 0.42700839042663574
# 곡 제목: When I´m Still Getting Over You (Feat. Paige), 감정: neutral, score: 0.9660041332244873
# 곡 제목: Call Me Maybe, 감정: neutral, score: 0.9999743700027466
# 곡 제목: boyfriend, 감정: anger, disapproval, score: 0.5135056972503662, 0.2514307498931885
# 곡 제목: Shivers, 감정: love, neutral, score: 0.6778519749641418, 0.3183166980743408
# 곡 제목: Checklist (Feat. Chromeo), 감정: neutral, score: 0.9589255452156067
# 곡 제목: Hero, 감정: disapproval, annoyance, score: 0.8209816813468933, 0.12471240013837814
# 곡 제목: In The Stars, 감정: sadness, neutral, score: 0.8698367476463318, 0.054368093609809875
# 곡 제목: 24K Magic, 감정: neutral, score: 0.9999910593032837
# 곡 제목: Me Too, 감정: gratitude, score: 0.988562822341919
# 곡 제목: Cruel Summer, 감정: fear, neutral, score: 0.8683842420578003, 0.06478849053382874
# 곡 제목: 6 months, 감정: love, score: 0.9983953833580017
# 곡 제목: Water, 감정: neutral, score: 0.99992835521698
# 곡 제목: Juice, 감정: neutral, score: 0.9998914003372192
# 곡 제목: Backyard Boy, 감정: fear, score: 0.9958899617195129
# 곡 제목: drivers license, 감정: love, score: 0.9593441486358643
# 곡 제목: Peter Pan Was Right, 감정: neutral, score: 0.9999825954437256
# 곡 제목: Hold On Tight, 감정: neutral, score: 0.9999434947967529
# 곡 제목: FRIENDS, 감정: annoyance, anger, score: 0.6383396983146667, 0.26640889048576355
# 곡 제목: Bright Blue Skies, 감정: disapproval, annoyance, score: 0.7488901615142822, 0.1850610375404358
# 곡 제목: deja vu, 감정: amusement, score: 0.9973219037055969
# 곡 제목: Shape Of My Heart, 감정: neutral, score: 0.9999804496765137
# 곡 제목: Taste, 감정: neutral, amusement, score: 0.5204774737358093, 0.39343470335006714
# 곡 제목: Love Someone, 감정: fear, love, score: 0.7446866035461426, 0.2454642653465271
# 곡 제목: Easy On Me, 감정: neutral, score: 0.9983075857162476
# 곡 제목: Kings & Queens, 감정: neutral, score: 0.9997803568840027
# 곡 제목: Before You, 감정: love, neutral, score: 0.6604236960411072, 0.2862158715724945
# 곡 제목: Painkiller, 감정: neutral, score: 0.9993276596069336
# 곡 제목: Everglow, 감정: love, neutral, score: 0.8723769783973694, 0.11240741610527039
# 곡 제목: Love Me Like You Do, 감정: love, score: 0.931726336479187
# 곡 제목: a thousand years, 감정: love, score: 0.9298316240310669
# 곡 제목: Rains in Heaven, 감정: love, score: 0.9997555613517761
# 곡 제목: come out and play, 감정: fear, nervousness, score: 0.45424792170524597, 0.4075959622859955
# 곡 제목: Pink + White, 감정: neutral, love, score: 0.7087388634681702, 0.2902446389198303
# 곡 제목: Never Be the Same, 감정: neutral, anger, score: 0.8311623930931091, 0.12678085267543793
# 곡 제목: Lover, 감정: love, score: 0.9615260362625122
# 곡 제목: drunk, 감정: love, score: 0.9994702935218811
# 곡 제목: Marvin Gaye (Feat. Meghan Trainor), 감정: neutral, score: 0.999916672706604
# 곡 제목: so good, 감정: disappointment, annoyance, score: 0.5012975335121155, 0.3016933500766754
# 곡 제목: I Don't Care, 감정: love, score: 0.9869325757026672
# 곡 제목: City Of Stars (From "La La Land" Soundtrack), 감정: love, score: 0.9940371513366699
# 곡 제목: Toxic, 감정: embarrassment, nervousness, score: 0.5650160908699036, 0.13109222054481506
# 곡 제목: Crazy AF, 감정: love, score: 0.999356210231781
# 곡 제목: Yellow Hearts, 감정: neutral, score: 0.9999436140060425
# 곡 제목: How Do I Say Goodbye, 감정: fear, score: 0.9985857009887695

# %%
df.to_csv("melon_pop_lyrics_with_emotions.csv", index=False)
